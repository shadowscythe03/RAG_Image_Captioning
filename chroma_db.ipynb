# %%
# !wget http://images.cocodataset.org/zips/train2017.zip
# !unzip train2017.zip -d ./coco/

# Captions annotations
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip annotations_trainval2017.zip -d ./coco/
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: ./coco/train2017/000000249290.jpg
#  extracting: ./coco/train2017/000000025529.jpg
#  extracting: ./coco/train2017/000000316928.jpg
#  extracting: ./coco/train2017/000000337866.jpg
#  extracting: ./coco/train2017/000000547768.jpg
#  extracting: ./coco/train2017/000000423162.jpg
#  extracting: ./coco/train2017/000000224149.jpg
#  extracting: ./coco/train2017/000000117841.jpg
#  extracting: ./coco/train2017/000000251660.jpg
#  extracting: ./coco/train2017/000000110997.jpg
#  extracting: ./coco/train2017/000000424728.jpg
#  extracting: ./coco/train2017/000000384745.jpg
#  extracting: ./coco/train2017/000000475535.jpg
#  extracting: ./coco/train2017/000000252604.jpg
#  extracting: ./coco/train2017/000000002525.jpg
#  extracting: ./coco/train2017/000000547307.jpg
#  extracting: ./coco/train2017/000000546568.jpg
#  extracting: ./coco/train2017/000000002024.jpg
#  extracting: ./coco/train2017/000000162559.jpg
# ...

# %%
# !git clone --single-branch --branch feature/add_transformers https://github.com/OFA-Sys/OFA.git
# Out:
# fatal: destination path 'OFA' already exists and is not an empty directory.

# %%
# !pip install OFA/transformers/
# Out:
# Processing ./OFA/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.18.0.dev0-py3-none-any.whl size=3916872 sha256=421c974a4c173751c60fc18477490842389b5532014c10697a412e012055ccf5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zsh8cbl1/wheels/db/a7/00/fa92e9c8cb27059f811370510b1105da67c202f293bf0adfb1
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.18.0.dev0
#     Uninstalling transformers-4.18.0.dev0:
#       Successfully uninstalled transformers-4.18.0.dev0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.4/20.4 MB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 81.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 15.5 MB/s eta 0:00:00
# ...

# %%
# !pip install torch torchvision pillow tqdm  open_clip_torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import os, json
from PIL import Image
from tqdm import tqdm
import torch
from torch.utils.data import DataLoader
from torchvision.datasets import CocoCaptions
from torchvision import transforms
import chromadb
import numpy as np
import open_clip
# from transformers import OFATokenizer, OFAModel

# %%
# !unzip chroma_db.zip
# Out:
# Archive:  chroma_db.zip
# replace chroma_db/b38fdc71-0167-44e0-8557-3ba91f31c02f/data_level0.bin? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: chroma_db/b38fdc71-0167-44e0-8557-3ba91f31c02f/data_level0.bin
#   inflating: chroma_db/b38fdc71-0167-44e0-8557-3ba91f31c02f/header.bin
#   inflating: chroma_db/b38fdc71-0167-44e0-8557-3ba91f31c02f/index_metadata.pickle
#   inflating: chroma_db/b38fdc71-0167-44e0-8557-3ba91f31c02f/length.bin
#   inflating: chroma_db/b38fdc71-0167-44e0-8557-3ba91f31c02f/link_lists.bin
#   inflating: chroma_db/chroma.sqlite3

# %%
# 3️⃣ Paths
COCO_IMG_DIR = "./coco/train2017"
COCO_ANN_FILE = "./coco/annotations/captions_train2017.json"
assert os.path.exists(COCO_IMG_DIR)
assert os.path.exists(COCO_ANN_FILE)

# 4️⃣ Persistent Chroma setup
chroma_dir = "./chroma_db"
# client = chromadb.PersistentClient(path=chroma_dir)
# # Create or get collection
# if "coco_clip_embeddings" in [c.name for c in client.list_collections()]:
#     collection = client.get_collection("coco_clip_embeddings")
# else:
#     collection = client.create_collection("coco_clip_embeddings")

# 5️⃣ Load CLIP
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, _, clip_preprocess = open_clip.create_model_and_transforms("ViT-B-32", pretrained="openai")
clip_model = clip_model.to(device)
clip_model.eval()

# 6️⃣ Load COCO annotations
# with open(COCO_ANN_FILE, "r") as f:
#     coco_data = json.load(f)

# annotations = coco_data["annotations"]
# img_id_to_path = {int(fn.split('.')[0]): os.path.join(COCO_IMG_DIR, fn)
#                   for fn in os.listdir(COCO_IMG_DIR) if fn.endswith(".jpg")}

# # 7️⃣ Encode images & store embeddings + captions
# batch_embeds = []
# batch_docs = []
# batch_ids = []

# print("🔹 Encoding images and indexing in Chroma...")
# for ann in tqdm(annotations):  # demo limit
#     img_id = ann["image_id"]
#     ann_id = ann["id"]
#     caption = ann["caption"]
#     img_path = img_id_to_path.get(img_id)
#     if not os.path.exists(img_path):
#         continue

#     # Encode image
#     image = clip_preprocess(Image.open(img_path)).unsqueeze(0).to(device)
#     with torch.no_grad():
#         img_emb = clip_model.encode_image(image)
#         img_emb /= img_emb.norm(dim=-1, keepdim=True)
#         emb = img_emb.cpu().numpy()[0]

#     batch_embeds.append(emb)
#     batch_docs.append(caption)
#     batch_ids.append(f"{img_id}_{ann_id}")  # unique ID

#     if len(batch_embeds) == 256:
#         collection.add(
#             embeddings=np.array(batch_embeds).tolist(),
#             documents=batch_docs,
#             ids=batch_ids
#         )
#         batch_embeds, batch_docs, batch_ids = [], [], []

# # Add remaining
# if batch_embeds:
#     collection.add(
#         embeddings=np.array(batch_embeds).tolist(),
#         documents=batch_docs,
#         ids=batch_ids
#     )


# print("✅ Chroma database saved.")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# open_clip_model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# ...

# %%
import torch
import open_clip

device = "cuda" if torch.cuda.is_available() else "cpu"

clip_model, _, clip_preprocess = open_clip.create_model_and_transforms(
    "ViT-B-32",
    pretrained="openai"
)
clip_model = clip_model.to(device)
clip_model.eval()

print("✅ Model loaded successfully on", device)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# open_clip_model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# ✅ Model loaded successfully on cpu

# %%
# !zip -r chroma_db.zip ./chroma_db

# %%
from google.colab import files
files.download("/content/chroma_db.zip")

# %%
chroma_dir = "./chroma_db"
client = chromadb.PersistentClient(path=chroma_dir)
collection = client.get_collection("coco_clip_embeddings")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipython-input-3224829465.py in <cell line: 0>()
#       1 chroma_dir = "./chroma_db"
#       2 client = chromadb.PersistentClient(path=chroma_dir)
# ----> 3 collection = client.get_collection("coco_clip_embeddings")
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/client.py in get_collection(self, name, embedding_function, data_loader)
#     206         data_loader: Optional[DataLoader[Loadable]] = None,
#     207     ) -> Collection:
# --> 208         model = self._server.get_collection(
#     209             name=name,
#     210             tenant=self.tenant,
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/rust.py in get_collection(self, name, tenant, database)
#     252         database: str = DEFAULT_DATABASE,
#     253     ) -> CollectionModel:
# ...

# %%
def retrieve_topk_captions_from_image_tensor(img_tensor, top_k=5):
    with torch.no_grad():
        img_emb = clip_model.encode_image(img_tensor)
        img_emb /= img_emb.norm(dim=-1, keepdim=True)
    query_emb = img_emb.cpu().numpy()[0].tolist()
    results = collection.query(query_embeddings=[query_emb], n_results=top_k)
    return " ".join(results["documents"][0])

# %%
# !git lfs install
# !git clone https://huggingface.co/OFA-Sys/OFA-tiny
# !git clone https://huggingface.co/OFA-Sys/OFA-tiny

# %%
# ckpt_dir = "./OFA-tiny"
# tokenizer = OFATokenizer.from_pretrained(ckpt_dir)
# ofa_model = OFAModel.from_pretrained(ckpt_dir).to(device)
# ofa_model.train()

# Image preprocessing for OFA
mean, std = [0.5,0.5,0.5], [0.5,0.5,0.5]
resolution = 224  # Change from 256 to 224
patch_transform = transforms.Compose([
    lambda image: image.convert("RGB"),
    transforms.Resize((resolution, resolution)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5,0.5,0.5], std=[0.5,0.5,0.5])
])

# %%
# =============================
# 7️⃣ Collate function for dynamic padding
# =============================
def collate_fn(batch):
    imgs, captions = zip(*batch)
    imgs = torch.stack(imgs, dim=0)

    input_ids_list, attention_masks_list, labels_list = [], [], []

    for img_tensor, caption in zip(imgs, captions):
        # Retrieve top-k captions
        context_text = retrieve_topk_captions_from_image_tensor(img_tensor.unsqueeze(0))
        prompt = f"{context_text} what does the image describe?"

        # Tokenize prompt dynamically
        inputs = tokenizer(prompt, return_tensors="pt", padding=True)
        input_ids_list.append(inputs.input_ids[0])
        attention_masks_list.append(inputs.attention_mask[0])

        # Tokenize target caption
        label_ids = tokenizer(caption, return_tensors="pt", padding=True).input_ids[0]
        label_ids[label_ids == tokenizer.pad_token_id] = -100
        labels_list.append(label_ids)

    # Pad all sequences in the batch to the max length in the batch
    input_ids = torch.nn.utils.rnn.pad_sequence(input_ids_list, batch_first=True, padding_value=tokenizer.pad_token_id)
    attention_mask = torch.nn.utils.rnn.pad_sequence(attention_masks_list, batch_first=True, padding_value=0)
    labels = torch.nn.utils.rnn.pad_sequence(labels_list, batch_first=True, padding_value=-100)

    return imgs, input_ids, attention_mask, labels

# =============================
# 8️⃣ DataLoader with dynamic padding
# =============================
dataset = CocoCaptions(root=COCO_IMG_DIR, annFile=COCO_ANN_FILE, transform=patch_transform)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# Optimizer
optimizer = torch.optim.AdamW(ofa_model.parameters(), lr=5e-5)

# =============================
# 9️⃣ Fine-tuning loop
# =============================
print("🚀 Starting OFA fine-tuning with full retrieved context...")

for step, (img_tensor, input_ids, attention_mask, labels) in enumerate(dataloader):
    try:
        img_tensor = img_tensor.to(device)
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        labels = labels.to(device)

        outputs = ofa_model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            patch_images=img_tensor,
            labels=labels
        )
        loss = outputs.loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % 50 == 0:
            print(f"Step {step} | Loss: {loss.item():.4f}")

        # For demo in Colab, limit number of steps
        if step == 100:
            break

    except Exception as e:
        print(f"⚠️ Skipped batch due to: {e}")

# =============================
# 1️⃣0️⃣ Save fine-tuned model
# =============================
save_dir = "./ofa_coco_clip_rag_finetuned"
os.makedirs(save_dir, exist_ok=True)
ofa_model.save_pretrained(save_dir)
tokenizer.save_pretrained(save_dir)
print(f"✅ Fine-tuned OFA saved at {save_dir}")

# %%
# !rm -rf ~/.cache/huggingface/hub

# %%
import os
import random
from PIL import Image
from IPython.display import display

# 1️⃣ Get 10 random images from COCO train folder
img_dir = "/content/coco/train2017"
all_imgs = [f for f in os.listdir(img_dir) if f.endswith(".jpg")]
random_imgs = random.sample(all_imgs, 10)

# 2️⃣ Loop through images
for img_name in random_imgs:
    img_path = os.path.join(img_dir, img_name)
    img = Image.open(img_path)
    patch_img = patch_transform(img).unsqueeze(0).to(device)

    # 3️⃣ Retrieve top-k captions
    top_k = 5
    context_texts = retrieve_topk_captions_from_image_tensor(patch_img, top_k=top_k)

    # 4️⃣ Display image
    display(img)

    # 5️⃣ Print retrieved captions
    print(f"🔹 Retrieved Top-{top_k} Captions for {img_name}:")
    for i, caption in enumerate(context_texts.split(". ")):
        if caption.strip():
            print(f"{i+1}. {caption.strip()}.")

    # # 6️⃣ Generate caption using OFA
    # prompt = f"what does the image describe?"
    # inputs = tokenizer(prompt, return_tensors="pt").to(device)

    # gen = ofa_model.generate(
    #     inputs.input_ids,
    #     patch_images=patch_img,
    #     num_beams=5,
    #     no_repeat_ngram_size=3
    # )
    # generated_caption = tokenizer.batch_decode(gen, skip_special_tokens=True)[0]

    # # 7️⃣ Display generated caption
    # print(f"🖼️ OFA Generated Caption: {generated_caption}\n")
    # print("-" * 80)
